# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_excel(r"C:\Users\jyama\UCSD\MGT 153\Final_Project.xlsx")

# %%
df.head()
# Out:
#                        name platform  year_of_release     genre publisher  \
# 0               Weii Sports     Weii             2006    Sports     Ninti
# 1        Marrison Kart Weii     Weii             2008    Racing     Ninti
# 2        Weii Sports Resort     Weii             2009    Sports     Ninti
# 3  New Super Marrison Bros.       DS             2006  Platform     Ninti
# 4                 Weii Play     Weii             2006      Misc     Ninti
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  critic_count  \
# 0  41360000  28960000   3770000      8450000           7.6          51.0
# 1  15680000  12760000   3790000      3290000           8.2          73.0
# 2  15610000  10930000   3280000      2950000           8.0          73.0
# 3  11280000   9140000   6500000      2880000           8.9          65.0
# 4  13960000   9180000   2930000      2840000           5.8          41.0
#
#    user_score  user_count developer rating  is_puzzle  is_role
# ...

# %%
list1 = [0]*8063
list2 = [1]*8063
list3 = [2]*8063
list4 = [3]*8063

# %%
df_new1 = df.drop(['eu_sales','jp_sales','other_sales'], axis = 1)
df_new1['region'] = list1
df_new1 = df_new1.rename(columns={"na_sales": "sales"})
df_new1.head()
# Out:
#                        name platform  year_of_release     genre publisher  \
# 0               Weii Sports     Weii             2006    Sports     Ninti
# 1        Marrison Kart Weii     Weii             2008    Racing     Ninti
# 2        Weii Sports Resort     Weii             2009    Sports     Ninti
# 3  New Super Marrison Bros.       DS             2006  Platform     Ninti
# 4                 Weii Play     Weii             2006      Misc     Ninti
#
#       sales  critic_score  critic_count  user_score  user_count developer  \
# 0  41360000           7.6          51.0         8.0       322.0     Ninti
# 1  15680000           8.2          73.0         8.3       709.0     Ninti
# 2  15610000           8.0          73.0         8.0       192.0     Ninti
# 3  11280000           8.9          65.0         8.5       431.0     Ninti
# 4  13960000           5.8          41.0         6.6       129.0     Ninti
#
#   rating  is_puzzle  is_role  region
# 0      E          0        0       0
# ...

# %%
df_new2 = df.drop(['na_sales','jp_sales','other_sales'], axis = 1)
df_new2['region'] = list2
df_new2 = df_new2.rename(columns={"eu_sales": "sales"})
df_new2.head()
# Out:
#                        name platform  year_of_release     genre publisher  \
# 0               Weii Sports     Weii             2006    Sports     Ninti
# 1        Marrison Kart Weii     Weii             2008    Racing     Ninti
# 2        Weii Sports Resort     Weii             2009    Sports     Ninti
# 3  New Super Marrison Bros.       DS             2006  Platform     Ninti
# 4                 Weii Play     Weii             2006      Misc     Ninti
#
#       sales  critic_score  critic_count  user_score  user_count developer  \
# 0  28960000           7.6          51.0         8.0       322.0     Ninti
# 1  12760000           8.2          73.0         8.3       709.0     Ninti
# 2  10930000           8.0          73.0         8.0       192.0     Ninti
# 3   9140000           8.9          65.0         8.5       431.0     Ninti
# 4   9180000           5.8          41.0         6.6       129.0     Ninti
#
#   rating  is_puzzle  is_role  region
# 0      E          0        0       1
# ...

# %%
df_new3 = df.drop(['na_sales','eu_sales','other_sales'], axis = 1)
df_new3['region'] = list3
df_new3 = df_new3.rename(columns={"jp_sales": "sales"})
df_new3.head()
# Out:
#                        name platform  year_of_release     genre publisher  \
# 0               Weii Sports     Weii             2006    Sports     Ninti
# 1        Marrison Kart Weii     Weii             2008    Racing     Ninti
# 2        Weii Sports Resort     Weii             2009    Sports     Ninti
# 3  New Super Marrison Bros.       DS             2006  Platform     Ninti
# 4                 Weii Play     Weii             2006      Misc     Ninti
#
#      sales  critic_score  critic_count  user_score  user_count developer  \
# 0  3770000           7.6          51.0         8.0       322.0     Ninti
# 1  3790000           8.2          73.0         8.3       709.0     Ninti
# 2  3280000           8.0          73.0         8.0       192.0     Ninti
# 3  6500000           8.9          65.0         8.5       431.0     Ninti
# 4  2930000           5.8          41.0         6.6       129.0     Ninti
#
#   rating  is_puzzle  is_role  region
# 0      E          0        0       2
# ...

# %%
df_new4 = df.drop(['na_sales','eu_sales','jp_sales'], axis = 1)
df_new4['region'] = list4
df_new4 = df_new4.rename(columns={"other_sales": "sales"})
df_new4.head()
# Out:
#                        name platform  year_of_release     genre publisher  \
# 0               Weii Sports     Weii             2006    Sports     Ninti
# 1        Marrison Kart Weii     Weii             2008    Racing     Ninti
# 2        Weii Sports Resort     Weii             2009    Sports     Ninti
# 3  New Super Marrison Bros.       DS             2006  Platform     Ninti
# 4                 Weii Play     Weii             2006      Misc     Ninti
#
#      sales  critic_score  critic_count  user_score  user_count developer  \
# 0  8450000           7.6          51.0         8.0       322.0     Ninti
# 1  3290000           8.2          73.0         8.3       709.0     Ninti
# 2  2950000           8.0          73.0         8.0       192.0     Ninti
# 3  2880000           8.9          65.0         8.5       431.0     Ninti
# 4  2840000           5.8          41.0         6.6       129.0     Ninti
#
#   rating  is_puzzle  is_role  region
# 0      E          0        0       3
# ...

# %%
frames = [df_new1, df_new2, df_new3, df_new4]

df_new = pd.concat(frames)
df_new.head()
# Out:
#                        name platform  year_of_release     genre publisher  \
# 0               Weii Sports     Weii             2006    Sports     Ninti
# 1        Marrison Kart Weii     Weii             2008    Racing     Ninti
# 2        Weii Sports Resort     Weii             2009    Sports     Ninti
# 3  New Super Marrison Bros.       DS             2006  Platform     Ninti
# 4                 Weii Play     Weii             2006      Misc     Ninti
#
#       sales  critic_score  critic_count  user_score  user_count developer  \
# 0  41360000           7.6          51.0         8.0       322.0     Ninti
# 1  15680000           8.2          73.0         8.3       709.0     Ninti
# 2  15610000           8.0          73.0         8.0       192.0     Ninti
# 3  11280000           8.9          65.0         8.5       431.0     Ninti
# 4  13960000           5.8          41.0         6.6       129.0     Ninti
#
#   rating  is_puzzle  is_role  region
# 0      E          0        0       0
# ...

# %%
len(df_new)
# Out:
# 32252

# %%
32252/4
# Out:
# 8063.0

# %%
df_new.to_excel(r"C:\Users\jyama\UCSD\MGT 153\AB_region.xlsx")
